# %%
import random
import matplotlib.pyplot as plt
from scipy import interpolate
import numpy as np

# %%
COUNT_OF_POINTS = 20
LEFT = -20
RIGHT = 20
EPS = 0.01

# %%
x = random.sample(range(LEFT, RIGHT), COUNT_OF_POINTS)
y = random.sample(range(LEFT, RIGHT), COUNT_OF_POINTS)

# %%
points_range = np.arange(min(x), max(x), EPS)
interpolated = interpolate.interp1d(x, y, kind='quadratic')

# %%
import modules.quadratic as qu

custom_eval = qu.quadratic(x, y, points_range)

# %%
plt.plot(x, y, "o", label="True values")
plt.plot(points_range, interpolated(points_range), '-', label="quadratic")
plt.plot(points_range, custom_eval, '-', label="my")
plt.legend()
